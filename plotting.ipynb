# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('NYSE_daily_prices_A.csv',parse_dates=['date'])
df.head(2)
# Out:
#   exchange stock_symbol       date  stock_price_open  stock_price_high  \
# 0     NYSE          AEA 2010-02-08              4.42              4.42
# 1     NYSE          ASP 2010-02-08             11.87             12.13
#
#    stock_price_low  stock_price_close  stock_volume  stock_price_adj_close
# 0             4.21               4.24        205500                   4.24
# 1            11.82              11.89         18900                  11.89

# %%
df[df['stock_symbol']=='AEA']['date'].dt.year == 2010
df1 =  df[(df['date'].dt.year == 2010) & (df['date'].dt.month == 1) & (df['stock_symbol'] == 'AEA')]

# %%
plt.xlabel('Day')
plt.ylabel('stock_price_close')
plt.title('stock price close')
plt.plot(df1['date'],df1['stock_price_open'],color='green',linewidth=2, linestyle='dotted')

# %%
x=[1,2,3,4,5,6,7]
y=[12.73,13.06,13.18,12.91,13.49,13.67,13.36]

# %%
plt.xlabel('Day')
plt.ylabel('stock_price_close')
plt.title('stock price close')
plt.plot(x,y,color='green',linewidth=5, linestyle='dotted')

# %%
days=[1,2,3,4,5,6]
high_s=[13.53,13.19,13.29,13.89,13.9,13.39]
low_s=[12.93,12.61,12.9,13.43,13.52,12.91]
close_s=[13.06,13.18,12.91,13.49,13.67,13.36]

# %%
plt.plot(days, high_s, label="stock_price_high")
plt.plot(days, low_s, label="stock_price_low")
plt.plot(days, close_s, label="stock_price_close")

plt.xlabel('day')
plt.ylabel('stock price')
plt.title('stock')
plt.legend(loc='best')

# %%
plt.plot(days, high_s, label="stock_price_high")
plt.plot(days, low_s, label="stock_price_low")
plt.plot(days, close_s, label="stock_price_close")

plt.xlabel('day')
plt.ylabel('stock price')
plt.title('stock')

plt.legend(loc='upper right',shadow=True,fontsize='large')

# %%
# bar graph
stock_symbol=['AA','AEA','ACO','ABX']
stock_volume=[90,136,89,27]

# %%
import numpy as np
xpos = np.arange(len(stock_symbol))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,stock_volume, label="stock_volume")

plt.xticks(xpos,stock_symbol)
plt.ylabel("stock_volume")
plt.title('Stocks Symbol')
plt.legend()

# %%
# multiple bar
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2,stock_volume, width=0.4, label="stock_volume")
plt.bar(xpos+0.2,profit, width=0.4,label="stock_volume_1")

plt.xticks(xpos,stock_symbol)
plt.ylabel("stock_volume")
plt.title('Stocks Symbol')
plt.legend()

# %%
plt.barh(xpos,stock_symbol, label="Revenue")

plt.yticks(xpos,stock_symbol)
plt.ylabel("stock_volume")
plt.title('Stocks Symbol')
plt.legend()

# %%
stock_price_adj_close = [13.06,13.18,12.91,13.49,13.64,13.33,12.7,12.89,13.27,13.51,13.36,13.37,14.22]
plt.hist(stock_price_adj_close, rwidth=0.8) # by default number of bins is set to 10
# Out:
# (array([1., 2., 1., 2., 3., 2., 1., 0., 0., 1.]),
#  array([12.7  , 12.852, 13.004, 13.156, 13.308, 13.46 , 13.612, 13.764,
#         13.916, 14.068, 14.22 ]),
#  <a list of 10 Patch objects>)

# %%
# bins parameter
plt.hist(stock_price_adj_close,rwidth=0.5,bins=4)
# Out:
# (array([4., 5., 3., 1.]),
#  array([12.7 , 13.08, 13.46, 13.84, 14.22]),
#  <a list of 4 Patch objects>)

# %%
# multi data sample in histogram
plt.xlabel("stock_symbol")
plt.ylabel("stock_price_open")
plt.title("stock_price_open")

AA = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
AEA = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([AA,AEA], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['AA','AEA'])
plt.legend()

# %%
# pie chart
exp_vals = [1400,600,300,410,250]
exp_labels = ["AA","AEA","AOE","ALQ","ALY"]
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0xb0d6e984e0>,
# ...
#  [Text(0.0932866,1.09604,'AA'),
#   Text(-0.982218,-0.495224,'AEA'),
#   Text(-0.162847,-1.08788,'AOE'),
#   Text(0.62561,-0.904772,'ALQ'),
#   Text(1.0615,-0.288458,'ALY')])

# %%
# draw pie chart at perfect circle
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %%
# show percentage
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5)
plt.show()

# %%
# explode
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2])
plt.show()

# %%
# counter clock and properties
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2],counterclock=True, startangle=45)
plt.show()

# %%
# save file
exp_vals = [1400,600,300,410,250]
exp_labels = ["AA","AEA","AOE","ALQ","ALX"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("piechart.jpg", bbox_inches="tight", pad_inches=1, transparent=True)
